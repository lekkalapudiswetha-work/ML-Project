# %% [markdown]
# # 06 Context-Aware Stacking
#
# Build the adaptive XGBoost stacker from base model probabilities and market regime features.

# %%
from run_pipeline import main

main()

# %%
import pandas as pd

pd.read_csv('results/metrics.csv')
